# %% [markdown]
# # 4th year and 7th semester exam analysis using python
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## this data will be visualize for some clarification analysis in the core subject marks and practical marks from the particular subjects from the electronics and communication engineering

# %% [markdown]
# ## SAMPLE QUESTIONS
#
# ### 1.How many section has attend the examination?
# ### 2.How many students got fail optical communication assesment examination?
# ### 3.How many percentage got first marks in adhoc and wireless sensor?
# ### 4.How many percentage students got fail marks in hospitality management?
# ### 5.name the percentage got higher number of arrears?

# %% [markdown]
# to import the python libraries for analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn as sk

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# get the data from the renewable resources

# %%
exam=pd.read_csv('/content/book1.csv')
exam.head(3)
# Out:
#   Unnamed: 0    Unnamed: 1   Unnamed: 2 Unnamed: 3          Unnamed: 4  \
# 0       S.NO      ROLL NO.      REG NO.        abc                NAME
# 1          1  2017PITEC164  2.11517E+11          D  AAKASH SIVAKUMAR S
# 2          2  2017PITEC101  2.11517E+11          A           ABIRAMI A
#
#   Unnamed: 5 EC8701 (AMW) Unnamed: 7 Unnamed: 8 ece1  ... Unnamed: 16  \
# 0        SEC           TP         AP      MARKS   TP  ...          AP
# 1          C           24         20         86   24  ...          24
# 2          A           21         21         95   21  ...          21
#
#   Unnamed: 17 ece4 Unnamed: 19 Unnamed: 20 ece4.1 Unnamed: 22 Unnamed: 23  \
# 0       MARKS   TP          AP       MARKS     TP          AP       MARKS
# 1          90   21          21          92     21          21          70
# 2          95   24          24          95     20          20          95
#
#   Unnamed: 24 Unnamed: 25
# 0        CGPA     ARREARS
# 1        3.98          16
# ...

# %%
exam.drop(exam.index[[0]])
# Out:
#     Unnamed: 0    Unnamed: 1   Unnamed: 2 Unnamed: 3  \
# 1            1  2017PITEC164  2.11517E+11          D
# 2            2  2017PITEC101  2.11517E+11          A
# 3            3  2017PITEC102  2.11517E+11          A
# 4            4  2017PITEC165  2.11517E+11          C
# 5            5  2017PITEC166  2.11517E+11          B
# ..         ...           ...          ...        ...
# 172        172  2017PITEC286  2.11517E+11          D
# 173        173  2017PITEC287  2.11517E+11          C
# 174        174  2017PITEC288  2.11517E+11          C
# 175        175  2017PITEC290  2.11517E+11          D
# 176        176  2016PITEC221  2.11516E+11          B
#
#                       Unnamed: 4 Unnamed: 5 EC8701 (AMW) Unnamed: 7  \
# 1             AAKASH SIVAKUMAR S          C           24         20
# 2                      ABIRAMI A          A           21         21
# 3                    ABIRAMI R P          A           21         21
# ...

# %% [markdown]
# to see the first and last person in the dataset

# %%
exam.head(3)
# Out:
#   Unnamed: 0    Unnamed: 1   Unnamed: 2 Unnamed: 3          Unnamed: 4  \
# 0       S.NO      ROLL NO.      REG NO.        abc                NAME
# 1          1  2017PITEC164  2.11517E+11          D  AAKASH SIVAKUMAR S
# 2          2  2017PITEC101  2.11517E+11          A           ABIRAMI A
#
#   Unnamed: 5 EC8701 (AMW) Unnamed: 7 Unnamed: 8 ece1  ... Unnamed: 16  \
# 0        SEC           TP         AP      MARKS   TP  ...          AP
# 1          C           24         20         86   24  ...          24
# 2          A           21         21         95   21  ...          21
#
#   Unnamed: 17 ece4 Unnamed: 19 Unnamed: 20 ece4.1 Unnamed: 22 Unnamed: 23  \
# 0       MARKS   TP          AP       MARKS     TP          AP       MARKS
# 1          90   21          21          92     21          21          70
# 2          95   24          24          95     20          20          95
#
#   Unnamed: 24 Unnamed: 25
# 0        CGPA     ARREARS
# 1        3.98          16
# ...

# %%
exam.tail(3)
# Out:
#     Unnamed: 0    Unnamed: 1   Unnamed: 2 Unnamed: 3  \
# 174        174  2017PITEC288  2.11517E+11          C
# 175        175  2017PITEC290  2.11517E+11          D
# 176        176  2016PITEC221  2.11516E+11          B
#
#                       Unnamed: 4 Unnamed: 5 EC8701 (AMW) Unnamed: 7  \
# 174                    YUVARAJ V          B           24         24
# 175                  BHUVANESH.P          C           24         24
# 176  Thippasani Sasi Kumar Reddy        NaN           24          0
#
#     Unnamed: 8 ece1  ... Unnamed: 16 Unnamed: 17 ece4 Unnamed: 19 Unnamed: 20  \
# 174         95   24  ...          24          95   21          21          95
# 175         70   24  ...          24          70   21          21          70
# 176          0   24  ...           0           0   21           0           0
#
#     ece4.1 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25
# 174     21          21          95         7.3           1
# ...

# %% [markdown]
# to explore the data from the dataset

# %%
exam.describe()
# Out:
#        Unnamed: 0 Unnamed: 1   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# count         177        177          177        177        177        176
# unique        177        177            3          5        177          4
# top          S.NO   ROLL NO.  2.11517E+11          A       NAME          A
# freq            1          1          175         60          1         79
#
#        EC8701 (AMW) Unnamed: 7 Unnamed: 8 ece1  ... Unnamed: 16 Unnamed: 17  \
# count           177        177        177  177  ...         177         177
# unique            3          8         19    3  ...           7          15
# top              24         24         95   24  ...          24          95
# freq             97         69         64   97  ...          74          64
#
#        ece4 Unnamed: 19 Unnamed: 20 ece4.1 Unnamed: 22 Unnamed: 23  \
# count   177         177         177    177         177         177
# unique    3           8          16      3           6          15
# ...

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    177 non-null    object
#  1   Unnamed: 1    177 non-null    object
#  2   Unnamed: 2    177 non-null    object
#  3   Unnamed: 3    177 non-null    object
#  4   Unnamed: 4    177 non-null    object
#  5   Unnamed: 5    176 non-null    object
#  6   EC8701 (AMW)  177 non-null    object
#  7   Unnamed: 7    177 non-null    object
#  8   Unnamed: 8    177 non-null    object
#  9   ece1          177 non-null    object
#  10  Unnamed: 10   177 non-null    object
#  11  Unnamed: 11   177 non-null    object
#  12  ece2          177 non-null    object
#  13  Unnamed: 13   177 non-null    object
#  14  Unnamed: 14   177 non-null    object
#  15  ece3          177 non-null    object
#  16  Unnamed: 16   177 non-null    object
#  17  Unnamed: 17   177 non-null    object
# ...

# %% [markdown]
# all the above dataset are objects or strings

# %%
exam.shape

# %% [markdown]
# the dataset have the 177 member detials with 26 columns details

# %%
exam.columns

# %% [markdown]
# all the columns header does not have clearly so we rename the columns in the dataset

# %%
exam.rename(columns={'Unnamed: 0':'serial_no',
                     'Unnamed: 1':'roll_no',
                     'Unnamed: 2':'regis_no',
                     'Unnamed: 4':'name',
                     'Unnamed: 5':'section',
                     'Unnamed: 7':'practical_marks_amw',
                     'EC8701 (AMW)':'assign_mark_amw',
                     'Unnamed: 8':'awm_exam_marks',
                     'ece1':'practical_marks_oc',
                     'Unnamed: 10':'assign_marks_oc',
                     'Unnamed: 11':'oc_exam_marks',
                     'ece2':'practical_marks_er',
                     'Unnamed: 13':'assign_mark_er',
                     'Unnamed: 14':'er_exam_marks',
                     'ece3':'practical_marks_aws',
                     'Unnamed: 16':'assign_marks_aws',
                     'Unnamed: 17':'aws_exam_marks',
                     'ece4':'practical_marks_hm',
                     'Unnamed: 19':'assign_marks_hm',
                     'Unnamed: 20':'hm_exam_marks',
                     'ece4.1':'practical_marks_nm',
                     'Unnamed: 22':'assign_marks_nm',
                     'Unnamed: 23':'nm_exam_marks',
                     'Unnamed: 24':'gpa',
                     'Unnamed: 25':'arrears'},inplace=True)

# %%
exam.columns
# Out:
# Index(['serial_no', 'roll_no', 'regis_no', 'Unnamed: 3', 'name', 'section',
#        'assign_mark_amw', 'practical_marks_amw', 'awm_exam_marks',
#        'practical_marks_oc', 'assign_marks_oc', 'oc_exam_marks',
#        'practical_marks_er', 'assign_mark_er', 'er_exam_marks',
#        'practical_marks_aws', 'assign_marks_aws', 'aws_exam_marks',
#        'practical_marks_hm', 'assign_marks_hm', 'hm_exam_marks',
#        'practical_marks_nm', 'assign_marks_nm', 'nm_exam_marks', 'gpa',
#        'arrears'],
#       dtype='object')

# %%
exam.drop(exam.index[[0]])
exam=exam.drop(exam.index[[0]])

# %% [markdown]
# to clean or arrange the data for easy analysis

# %%
exam.isna().sum()
# Out:
# serial_no              0
# roll_no                0
# regis_no               0
# Unnamed: 3             0
# name                   0
# section                1
# assign_mark_amw        0
# practical_marks_amw    0
# awm_exam_marks         0
# practical_marks_oc     0
# assign_marks_oc        0
# oc_exam_marks          0
# practical_marks_er     0
# assign_mark_er         0
# er_exam_marks          0
# practical_marks_aws    0
# assign_marks_aws       0
# aws_exam_marks         0
# practical_marks_hm     0
# assign_marks_hm        0
# hm_exam_marks          0
# practical_marks_nm     0
# assign_marks_nm        0
# nm_exam_marks          0
# gpa                    0
# arrears                0
# dtype: int64

# %%
exam.dropna(inplace=True)
exam.isna().sum()
# Out:
# serial_no              0
# roll_no                0
# regis_no               0
# Unnamed: 3             0
# name                   0
# section                0
# assign_mark_amw        0
# practical_marks_amw    0
# awm_exam_marks         0
# practical_marks_oc     0
# assign_marks_oc        0
# oc_exam_marks          0
# practical_marks_er     0
# assign_mark_er         0
# er_exam_marks          0
# practical_marks_aws    0
# assign_marks_aws       0
# aws_exam_marks         0
# practical_marks_hm     0
# assign_marks_hm        0
# hm_exam_marks          0
# practical_marks_nm     0
# assign_marks_nm        0
# nm_exam_marks          0
# gpa                    0
# arrears                0
# dtype: int64

# %% [markdown]
# they have 1 null values in the section so it can be cleared

# %% [markdown]
# to find the duplicated values in the dataset

# %%
exam[exam.duplicated()]
# Out:
# Empty DataFrame
# Columns: [serial_no, roll_no, regis_no, Unnamed: 3, name, section, assign_mark_amw, practical_marks_amw, awm_exam_marks, practical_marks_oc, assign_marks_oc, oc_exam_marks, practical_marks_er, assign_mark_er, er_exam_marks, practical_marks_aws, assign_marks_aws, aws_exam_marks, practical_marks_hm, assign_marks_hm, hm_exam_marks, practical_marks_nm, assign_marks_nm, nm_exam_marks, gpa, arrears]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# there is not any repeated values in the dataset

# %% [markdown]
# to remove the unnamed 3 columns beacause that is not want to analysis

# %%
del exam['roll_no']
exam
# Out:
#     serial_no     regis_no                         name section  \
# 1           1  2.11517E+11           AAKASH SIVAKUMAR S       C
# 2           2  2.11517E+11                    ABIRAMI A       A
# 3           3  2.11517E+11                  ABIRAMI R P       A
# 4           4  2.11517E+11                   AMARNATH D       C
# 5           5  2.11517E+11                ANBU PRIYAN M       C
# ..        ...          ...                          ...     ...
# 171       171  2.11517E+11              VUKYAM HARSHITH       C
# 172       172  2.11517E+11              YADDALA BHARGAV       C
# 173       173  2.11517E+11  YENNI VENKATA SAMPATH KUMAR       C
# 174       174  2.11517E+11                    YUVARAJ V       B
# 175       175  2.11517E+11                  BHUVANESH.P       C
#
#     assign_mark_amw practical_marks_amw awm_exam_marks practical_marks_oc  \
# 1                24                  20             86                 24
# ...

# %% [markdown]
# **DATA ANALYSIS FOR EXAMINATION SUBJECTS**

# %% [markdown]
# to find the no of students in each section

# %%
exam['section'].value_counts()
# Out:
# A    79
# B    50
# C    46
# Name: section, dtype: int64

# %%
plt.figure(figsize=(6,3))
plt.title('No of students present in each section')
sns.countplot(x='section',data=exam,color='violet')
plt.show()

# %% [markdown]
# section A has more number of students which has 79 students in the particular section

# %% [markdown]
# **1. ANTENNA AND MICROWAVE [EC 8701]**

# %% [markdown]
# to get the assignment marks for antenna and microwave subject

# %%
exam['assign_mark_amw'].value_counts()
# Out:
# 24    96
# 21    79
# Name: assign_mark_amw, dtype: int64

# %% [markdown]
# most of the students in the department has got marks of 24, 21 in the antenna and microwave subject

# %%
plt.figure(figsize=(3,4))

plt.title("Top marks in assesment for antenna and microwave ")
sns.barplot(y=exam['assign_mark_amw'].value_counts().values,
            x=exam['assign_mark_amw'].value_counts().index,
            color='m',
            saturation=1)
plt.show()

# %% [markdown]
# to compare themselves most of the students(96) got the 24 marks in assesment for amw

# %% [markdown]
# to get the practical marks for awm subject

# %%
exam['practical_marks_amw'].value_counts()
# Out:
# 24    69
# 21    68
# 20    16
# 18    13
# 16     8
# 15     1
# Name: practical_marks_amw, dtype: int64

# %% [markdown]
# in practical session most of the students got 24  21 in amw and 69 students got 24 and 68 students got

# %%
plt.figure(figsize=(4,2))
plt.title('practical marks in amw')
sns.barplot(x=exam['practical_marks_amw'].value_counts().values,
            y=exam['practical_marks_amw'].value_counts().index,
            color='b',)
# Out:
# <Axes: title={'center': 'practical marks in amw'}>

# %% [markdown]
# one students fails in practical exam session

# %% [markdown]
# to get the theory exam marks for amw

# %%
exam['awm_exam_marks'].value_counts()
# Out:
# 95     64
# 100    33
# 85     13
# 75     12
# 70     10
# 90      9
# 76      6
# 80      6
# 84      5
# 82      4
# 88      3
# 86      2
# 72      2
# 74      2
# 78      2
# 92      1
# 96      1
# Name: awm_exam_marks, dtype: int64

# %%
plt.figure(figsize=(6,3))
plt.title('students scored marks in awm')
sns.countplot(x='awm_exam_marks',data=exam,color='green')
plt.show()

# %% [markdown]
# most of the students got 95% marks in the in antenna and microwave subject

# %% [markdown]
# **2. OPTICAL COMMUNICATION [EC8751]**

# %% [markdown]
# to get the assesment marks for oc subject

# %%
exam['assign_marks_oc'].value_counts()
# Out:
# 24    73
# 21    69
# 20    12
# 16    11
# 18     9
# 15     1
# Name: assign_marks_oc, dtype: int64

# %% [markdown]
# 73 students are got 24 marks
# 69 students are gor 22 marks

# %% [markdown]
# A histogram is an approximate representation of the distribution of numerical data.

# %%
plt.figure(figsize=(4,3))
plt.title('assesment marks in optical communication')
sns.histplot(x='assign_marks_oc',data=exam,kde=True,color='brown')
plt.show()

# %% [markdown]
# to get the practical marks in the oc subject

# %%
exam['practical_marks_oc'].value_counts()
# Out:
# 24    96
# 21    79
# Name: practical_marks_oc, dtype: int64

# %%
plt.figure(figsize=(6,3))
plt.title('practical session marks in oc')
sns.countplot(x ='practical_marks_oc', data=exam, palette = "Set2")
plt.show()

# %% [markdown]
# to get the theory exam marks in optical communication

# %%
exam['oc_exam_marks'].value_counts()
# Out:
# 95     52
# 100    33
# 96     21
# 92     17
# 90     12
# 94      8
# 88      6
# 75      5
# 85      4
# 70      4
# 76      3
# 84      3
# 80      2
# 86      2
# 82      1
# 98      1
# 74      1
# Name: oc_exam_marks, dtype: int64

# %%
plt.figure(figsize=(6,3))
plt.title('student scored marks in optical communication')
sns.countplot(x='oc_exam_marks', data =exam,
              color="salmon",
              saturation = 0.1)
plt.show()

# %% [markdown]
# most of the students got 100 and 95 in optical communication subject

# %% [markdown]
# **3. EMBEDDED AND REAL TIME ANALYSIS [EC8791]**

# %% [markdown]
# to get the assesment marks data for er

# %%
exam['practical_marks_er'].value_counts()
# Out:
# 24    96
# 21    79
# Name: practical_marks_er, dtype: int64

# %%
plt.figure(figsize=(4,2))
plt.title('practical session marks in embedded and real time')
sns.countplot(x ='practical_marks_er', data = exam,color="salmon", facecolor=(0, 0, 0, 0),
                   linewidth=5,
                   edgecolor=sns.color_palette("BrBG", 2))
# Out:
# <Axes: title={'center': 'practical session marks in embedded and real time'}, xlabel='practical_marks_er', ylabel='count'>

# %% [markdown]
# more than 96% of students got 24 marks in practical session from emmbedded system and real time analysis

# %% [markdown]
# next after that we get from assement marks from the embedded system and real time analysis

# %%
exam['assign_mark_er'].value_counts()
# Out:
# 21    68
# 24    67
# 20    24
# 18    13
# 16     2
# 15     1
# Name: assign_mark_er, dtype: int64

# %%
plt.figure(figsize=(6,3))
plt.title('assessment marks in embedded system and real time analysis')
sns.countplot(x='assign_mark_er',data=exam,color='violet')
plt.show()

# %% [markdown]
# more than 120 students got 21 and 24 marks

# %% [markdown]
# to get the embedded and real time analysis exam marks

# %%
exam['er_exam_marks'].value_counts()
# Out:
# 95     63
# 94     44
# 100    33
# 92     11
# 90      6
# 88      5
# 84      2
# 85      2
# 75      2
# 80      2
# 70      2
# 96      1
# 86      1
# 82      1
# Name: er_exam_marks, dtype: int64

# %%
plt.figure(figsize=(6,3))
plt.title('students result for embedded system and real analysis')
sns.countplot(x ='er_exam_marks', data = exam,color='blue',
              saturation = 0.1)
plt.show()

# %% [markdown]
# 63 students and 44 students are got 95 and 94 marksin embedded system and real analysis

# %% [markdown]
# 63 and 44 students are got 95 and 94 marks in embedded system and real analysis

# %% [markdown]
# **4.ADHOC AND WIRELESS SENSOR EC[8702]**

# %% [markdown]
# to obtain the practical result in adhoc

# %%
exam['practical_marks_aws'].value_counts()
# Out:
# 24    96
# 21    79
# Name: practical_marks_aws, dtype: int64

# %%
plt.figure(figsize=(3,2))
plt.title('practical marks in embedded system')
sns.histplot(x='practical_marks_oc',data=exam,kde=True,color='brown')
plt.show()

# %% [markdown]
# to obtain the assessment score from the data for adhoc

# %%
exam['assign_marks_aws'].value_counts()
# Out:
# 24    74
# 21    68
# 20    16
# 18    11
# 16     6
# Name: assign_marks_aws, dtype: int64

# %%
plt.figure(figsize=(6,3))

plt.title("assesment marks for adhoc and wireless sensor")
sns.barplot(y=exam['assign_marks_aws'].value_counts().head(20).values,
            x=exam['assign_marks_aws'].value_counts().head(20).index,
            color='b',
            saturation=1)
plt.show()

# %% [markdown]
# more than 70 and 60 students are got 24 and 21 marks in  adhoc and wireless sensor

# %% [markdown]
# got marks from the adhoc and wireless sensor in exam results

# %%
exam['aws_exam_marks'].value_counts()
# Out:
# 95     64
# 100    33
# 90     25
# 86     13
# 82      9
# 88      9
# 85      6
# 84      5
# 76      3
# 70      3
# 75      2
# 80      2
# 78      1
# Name: aws_exam_marks, dtype: int64

# %%
plt.figure(figsize=(6,3))
plt.title('assessment marks in adhoc and wireless sensor')
sns.countplot(x='aws_exam_marks',data=exam,color='black')
plt.show()

# %% [markdown]
# more than 60 students got 95% marks in the adhoc subject

# %% [markdown]
# **4. HOSPITAL MANAGEMENT [OBM752]**

# %% [markdown]
# to obtain the assesment marks from the hospitality management

# %%
exam['assign_marks_hm'].value_counts()
# Out:
# 24    70
# 21    64
# 18    22
# 15    10
# 20     7
# 16     2
# Name: assign_marks_hm, dtype: int64

# %%
plt.figure(figsize=(3,2))
plt.title('assessment marks in hospitality management')
sns.histplot(x='assign_marks_hm',data=exam,kde=True,color='brown')
plt.show()

# %% [markdown]
# to obtain the practical marks from the hospitality management

# %%
exam['practical_marks_hm'].value_counts()
# Out:
# 21    96
# 24    79
# Name: practical_marks_hm, dtype: int64

# %%
plt.figure(figsize=(3,2))
plt.title('practical marks in hospitality management')
sns.countplot(x='practical_marks_hm',data=exam,color='green')
plt.show()

# %% [markdown]
# to obtain the exam marks from the hospitality management

# %%
exam['hm_exam_marks'].value_counts()
# Out:
# 95     61
# 90     33
# 100    33
# 94      9
# 92      7
# 88      7
# 86      5
# 75      4
# 82      4
# 70      4
# 96      3
# 85      2
# 84      2
# 80      1
# Name: hm_exam_marks, dtype: int64

# %%
plt.figure(figsize=(6,3))

plt.title("exam marks for hospitality and management")
sns.barplot(y=exam['hm_exam_marks'].value_counts().head(20).values,
            x=exam['hm_exam_marks'].value_counts().head(20).index,
            color='c',
            saturation=1)
plt.show()

# %% [markdown]
# most of the students are got 90 to 100 marks in hospitality management

# %% [markdown]
# **5. NAAN MUDHALVAN COURSE**

# %% [markdown]
# to analyze the assesment marks from the naan mudhalvan course

# %%
exam['assign_marks_nm'].value_counts()
# Out:
# 20    71
# 21    69
# 18    18
# 15    17
# Name: assign_marks_nm, dtype: int64

# %%
plt.figure(figsize=(6,3))
plt.title('assesment marks in hospitality management')
sns.countplot(x='assign_marks_nm',data=exam,color='orange')
plt.show()

# %% [markdown]
# more than 70 students got 21 marks in naan mudhalvan course assesment

# %% [markdown]
# to get the practical analyze from the naan mudhalvan course

# %%
exam['practical_marks_nm'].value_counts()
# Out:
# 21    96
# 20    79
# Name: practical_marks_nm, dtype: int64

# %%
plt.figure(figsize=(6,3))
plt.title('practical marks in hospitality management')
sns.countplot(x='practical_marks_nm',data=exam,color='pink')
plt.show()

# %% [markdown]
# in practical session they got 21 marks for 96 students

# %% [markdown]
# to analyze the results from the exam sesion from the naan mudhalvan course

# %%
exam['nm_exam_marks'].value_counts()
# Out:
# 95     64
# 100    33
# 85     17
# 70      9
# 90      9
# 75      9
# 80      9
# 78      7
# 76      6
# 82      5
# 74      3
# 84      3
# 86      1
# Name: nm_exam_marks, dtype: int64

# %%
plt.figure(figsize=(4,2))
plt.title('exam marks in naan mudhalvan course')
sns.histplot(x='nm_exam_marks',data=exam,kde=True,color='violet')
plt.show()

# %% [markdown]
# more than 60 students got 95 marks in naan mudhalvan course

# %%
plt.figure(figsize=(6,4))
plt.title('arrears in internal examination')
sns.countplot(x='arrears',data=exam,color='brown')
plt.show()

# %%
exam['arrears'].value_counts()
# Out:
# 0     70
# 1     36
# 2     12
# 8      6
# 3      6
# 9      4
# 13     4
# 4      4
# 11     4
# 18     3
# 6      3
# 14     3
# 21     3
# 12     3
# 16     2
# 7      2
# 15     2
# 20     2
# 5      2
# 10     2
# 25     1
# 19     1
# Name: arrears, dtype: int64

# %% [markdown]
# arrear exam refers to a type of examination taken by a student who has not yet passed a particular subject or paper in a previous attempt.

# %%
x=exam['arrears'].head(15)
y=exam['name'].head(15)
plt.title("arrear analysis")
plt.xlabel("Arrears")
plt.ylabel("student Name")
plt.bar(x, y,color=['blue','green','yellow','brown','black','pink','indigo'])
plt.show()

# %% [markdown]
# dhivagar and chalicheemala gunasekaran got 14 and 13 arrears in the whole examination

# %% [markdown]
# **GRADE POINT AVERAGE**
# Your grade point average (GPA) is the average result of all your grades and is calculated on a 7-point grading scale. 7 being the highest (HD), and 0 is the lowest (fail). The GPA calculator can help you determine if you are eligible for scholarships, programs such as Honours or admission to other universities.

# %%
x=exam['gpa'].head(10)
y=exam['name'].head(10)
plt.title("gpa analysis")
plt.xlabel("gpa")
plt.ylabel("student Name")
plt.bar(x, y,color=['orange','green','lavender','pink','blue','red','black','yellow','brown'])
plt.show()

# %% [markdown]
# aparna got 8.49 gpa in the whole examination

# %%
df = pd.DataFrame(exam)
df.round(1)
# Out:
#     serial_no       roll_no     regis_no Unnamed: 3  \
# 1           1  2017PITEC164  2.11517E+11          D
# 2           2  2017PITEC101  2.11517E+11          A
# 3           3  2017PITEC102  2.11517E+11          A
# 4           4  2017PITEC165  2.11517E+11          C
# 5           5  2017PITEC166  2.11517E+11          B
# ..        ...           ...          ...        ...
# 171       171  2017PITEC285  2.11517E+11          B
# 172       172  2017PITEC286  2.11517E+11          D
# 173       173  2017PITEC287  2.11517E+11          C
# 174       174  2017PITEC288  2.11517E+11          C
# 175       175  2017PITEC290  2.11517E+11          D
#
#                             name section assign_mark_amw practical_marks_amw  \
# 1             AAKASH SIVAKUMAR S       C              24                  20
# 2                      ABIRAMI A       A              21                  21
# 3                    ABIRAMI R P       A              21                  21
# ...

# %%
import plotly.express as pl
df = pl.data.tips()
fig = pl.pie(exam, values='arrears', names='arrears',title='arrear analysis using pie chart')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 9.31% students got 63 arrears for 21 students
# 7.98% students got 54 arrears for 18 students
# 7.68% students got 52 arrears for 13 students
# 7.09% students got 48 arrears for 8 students

# %% [markdown]
# # Answer for the sample questions
# ### 1.there are 3 section attend the examination(A,B,C)
# ### 2.16 Marks has got 11students and 18 marks got 9 students and 15 marks got 1 students
# ### 3.33 students got 100 marks for adhoc and sensor examination
# ### 4.nobody should fail in hospitality and management
# ### 5.9.31% of arrear is 63 arreas for the students in the particular institution
